# %%
import pyelsed
import cv2
import numpy as np
import glob
from scipy.spatial.transform import Rotation as R
import os
import matplotlib.pyplot as plt
import json
import open3d as o3d
from skimage.measure import LineModelND, ransac
from sklearn.cluster import KMeans
# from collections import Counter
from joblib import Parallel, delayed
from scipy import stats
params ={
    "perturb_len":6,
}
# Out:
# Jupyter environment detected. Enabling Open3D WebVisualizer.
# [Open3D INFO] WebRTC GUI backend enabled.
# [Open3D INFO] WebRTCWindowSystem: HTTP handshake server disabled.

# %% [markdown]
# ### Replace gt semantic labels with the predicted ones, evaluate accuracy and completeness

# %%
project_root_dir = '/data1/home/lucky/IROS25/SCORE/'
scene_list = ["a1d9da703c","689fec23d7","c173f62b15","69e5939669"]
scene_id = scene_list[0]
mask_folder = project_root_dir+f'/S1_a1d_segmentation_mask/'
# load data with ground truth semantic labels
data_query_path = os.path.join(project_root_dir,f'line_map_extractor/out/{scene_id}/query/{scene_id}_query_data.npy')
data_query = np.load(data_query_path,allow_pickle=True).item()
scene_line_2D_params = data_query['scene_line_2D_params']
scene_line_2D_points = data_query['scene_line_2D_points']
scene_line_2D_semantic_ids = data_query['scene_line_2D_semantic_ids']
scene_line_2D_end_points = data_query['scene_line_2D_end_points']
id_label_dict = data_query['id_label_dict']
id_label_dict[0] = 'unlabeled'
# load predicted semantic masks
mask_files = glob.glob(mask_folder + '*.npy')
mask_files.sort()
###
scene_line_2D_semantic_ids_new={}
total_num_lines = 0
total_num_wrong_predictions = 0
total_num_missing_predictions = 0
wrong_labels = {}
for mask_file in mask_files:
    image_sem_mask = np.load(mask_file)
    base_name=os.path.basename(mask_file).split(".")[0]
    if base_name not in scene_line_2D_points:
        continue
    line_2D_semantic_id = scene_line_2D_semantic_ids[base_name]
    line_2D_semantic_ids_new=[]
    missing_count = 0
    wrong_count = 0
    print("processing",base_name)
    line_2D_points = scene_line_2D_points[base_name]
    num_lines = len(line_2D_points)
    for j in range(num_lines):
        x = line_2D_points[j][0]
        y = line_2D_points[j][1]
        v = np.array([x[0]-x[-1],y[0]-y[-1]])
        v = v/np.linalg.norm(v)
        perturb_list = np.array([0,-1,1])*params['perturb_len']
        old_label = line_2D_semantic_id[j]
        semantic_buffer=[]
        for perturb_l in perturb_list:
            x_p = x + int(perturb_l*v[0])
            y_p = y + int(perturb_l*v[1])
            idx_valid0 = np.logical_and(x_p>=0,x_p<image_sem_mask.shape[1])
            idx_valid1 = np.logical_and(y_p>=0,y_p<image_sem_mask.shape[0])
            idx_valid = np.logical_and(idx_valid0,idx_valid1)
            x_p = x_p[idx_valid].astype(int)
            y_p = y_p[idx_valid].astype(int)
            for i in range(len(x_p)):
                if image_sem_mask[y_p[i],x_p[i]]==0:
                    continue
                semantic_buffer.append(image_sem_mask[y_p[i],x_p[i]])     
        if semantic_buffer==[]:  # no semantic label assigned
            new_label=0
            missing_count+=1
        else:
            new_labels = np.unique(semantic_buffer)
            if old_label not in new_labels: # wrong label assigned
                wrong_count+=1
                new_label = new_labels[0] # take the first label as the new label
            else:
                new_label = old_label
        #
        line_2D_semantic_ids_new.append(new_label)
        if new_label != old_label: # record the wrong prediction
            if (id_label_dict[old_label] + ' ' + id_label_dict[new_label]) not in wrong_labels:
                wrong_labels[id_label_dict[old_label] + ' ' + id_label_dict[new_label]] = 1
            else:
                wrong_labels[id_label_dict[old_label] + ' ' + id_label_dict[new_label]] += 1
            print(f'{base_name},line_{str(j)}, old label:{id_label_dict[old_label]}, new label:{id_label_dict[new_label]}')
    # statistics for this image          
    scene_line_2D_semantic_ids_new[base_name]=line_2D_semantic_ids_new
    total_num_lines += num_lines
    total_num_wrong_predictions += wrong_count
    total_num_missing_predictions += missing_count
print(f'scene {scene_id}, average wrong prediction ratio: {total_num_wrong_predictions/total_num_lines}, average missing prediction ratio: {total_num_missing_predictions/total_num_lines}')
# Out:
# processing frame_000070
# frame_000070,line_1, old label:wall, new label:sofa cushion
# frame_000070,line_2, old label:floor, new label:sofa cushion
# frame_000070,line_3, old label:sofa, new label:sofa cushion
# frame_000070,line_4, old label:door, new label:unlabeled
# frame_000070,line_5, old label:sofa, new label:sofa cushion
# frame_000070,line_6, old label:wall, new label:floor
# frame_000070,line_7, old label:sofa, new label:sofa cushion
# frame_000070,line_8, old label:wall, new label:unlabeled
# frame_000070,line_9, old label:sofa, new label:sofa cushion
# frame_000070,line_10, old label:door, new label:unlabeled
# frame_000070,line_12, old label:sofa, new label:sofa cushion
# processing frame_000150
# frame_000150,line_0, old label:door, new label:wall
# frame_000150,line_1, old label:door, new label:unlabeled
# frame_000150,line_4, old label:door, new label:unlabeled
# frame_000150,line_5, old label:floor, new label:door
# processing frame_000230
# frame_000230,line_0, old label:door, new label:unlabeled
# frame_000230,line_1, old label:wall, new label:unlabeled
# frame_000230,line_2, old label:door, new label:unlabeled
# frame_000230,line_3, old label:door, new label:unlabeled
# frame_000230,line_5, old label:sofa, new label:sofa cushion
# frame_000230,line_6, old label:sofa, new label:sofa cushion
# frame_000230,line_7, old label:sofa cushion, new label:unlabeled
# frame_000230,line_9, old label:sofa, new label:sofa cushion
# processing frame_000310
# frame_000310,line_2, old label:table, new label:keyboard
# frame_000310,line_4, old label:monitor, new label:computer tower
# frame_000310,line_7, old label:wall, new label:unlabeled
# frame_000310,line_11, old label:keyboard, new label:monitor
# processing frame_000390
# frame_000390,line_3, old label:table, new label:keyboard
# frame_000390,line_4, old label:table, new label:floor
# frame_000390,line_5, old label:monitor, new label:unlabeled
# frame_000390,line_12, old label:monitor, new label:unlabeled
# frame_000390,line_17, old label:table, new label:unlabeled
# frame_000390,line_18, old label:blinds, new label:window
# processing frame_000540
# frame_000540,line_1, old label:monitor, new label:unlabeled
# frame_000540,line_2, old label:monitor, new label:unlabeled
# frame_000540,line_7, old label:window, new label:unlabeled
# frame_000540,line_20, old label:monitor, new label:window
# frame_000540,line_34, old label:window sill, new label:unlabeled
# frame_000540,line_36, old label:monitor, new label:unlabeled
# frame_000540,line_38, old label:office chair, new label:unlabeled
# processing frame_000630
# frame_000630,line_2, old label:door, new label:window
# frame_000630,line_3, old label:storage cabinet, new label:door
# frame_000630,line_5, old label:coat hanger, new label:unlabeled
# frame_000630,line_8, old label:storage cabinet, new label:door
# frame_000630,line_11, old label:wall, new label:door
# processing frame_000710
# frame_000710,line_2, old label:storage cabinet, new label:door
# frame_000710,line_5, old label:storage cabinet, new label:door
# frame_000710,line_7, old label:coat hanger, new label:door
# processing frame_001180
# frame_001180,line_0, old label:door, new label:wall
# frame_001180,line_1, old label:door, new label:unlabeled
# frame_001180,line_2, old label:ceiling lamp, new label:unlabeled
# frame_001180,line_3, old label:ceiling lamp, new label:unlabeled
# frame_001180,line_4, old label:door, new label:wall
# frame_001180,line_5, old label:door, new label:unlabeled
# frame_001180,line_6, old label:door, new label:wall
# frame_001180,line_7, old label:door, new label:unlabeled
# frame_001180,line_9, old label:door, new label:wall
# frame_001180,line_11, old label:pipe, new label:unlabeled
# frame_001180,line_12, old label:door, new label:unlabeled
# frame_001180,line_14, old label:pipe, new label:unlabeled
# frame_001180,line_15, old label:ceiling, new label:unlabeled
# processing frame_001260
# frame_001260,line_3, old label:coat hanger, new label:unlabeled
# frame_001260,line_4, old label:ceiling lamp, new label:unlabeled
# frame_001260,line_5, old label:storage cabinet, new label:unlabeled
# frame_001260,line_11, old label:storage cabinet, new label:unlabeled
# frame_001260,line_13, old label:floor, new label:unlabeled
# processing frame_001340
# frame_001340,line_0, old label:storage cabinet, new label:file cabinet
# frame_001340,line_2, old label:door, new label:window
# frame_001340,line_4, old label:door, new label:wall
# frame_001340,line_5, old label:coat hanger, new label:unlabeled
# frame_001340,line_6, old label:coat hanger, new label:file cabinet
# frame_001340,line_7, old label:storage cabinet, new label:file cabinet
# frame_001340,line_9, old label:whiteboard, new label:unlabeled
# frame_001340,line_19, old label:storage cabinet, new label:file cabinet
# frame_001340,line_20, old label:storage cabinet, new label:file cabinet
# frame_001340,line_24, old label:door, new label:wall
# processing frame_001470
# frame_001470,line_1, old label:storage cabinet, new label:door
# frame_001470,line_3, old label:wall, new label:window
# frame_001470,line_4, old label:blinds, new label:unlabeled
# frame_001470,line_6, old label:window, new label:unlabeled
# frame_001470,line_7, old label:storage cabinet, new label:door
# frame_001470,line_11, old label:ceiling, new label:unlabeled
# frame_001470,line_13, old label:ceiling, new label:unlabeled
# frame_001470,line_14, old label:storage cabinet, new label:unlabeled
# frame_001470,line_15, old label:storage cabinet, new label:computer tower
# frame_001470,line_19, old label:office chair, new label:file cabinet
# frame_001470,line_22, old label:ceiling lamp, new label:unlabeled
# frame_001470,line_23, old label:wall, new label:unlabeled
# frame_001470,line_27, old label:wall, new label:unlabeled
# frame_001470,line_35, old label:table, new label:unlabeled
# frame_001470,line_38, old label:window, new label:unlabeled
# frame_001470,line_40, old label:keyboard, new label:unlabeled
# frame_001470,line_42, old label:ceiling, new label:unlabeled
# frame_001470,line_43, old label:storage cabinet, new label:door
# frame_001470,line_48, old label:ceiling, new label:unlabeled
# frame_001470,line_49, old label:ceiling, new label:unlabeled
# frame_001470,line_50, old label:ceiling, new label:unlabeled
# frame_001470,line_51, old label:file cabinet, new label:table
# frame_001470,line_52, old label:ceiling lamp, new label:unlabeled
# frame_001470,line_53, old label:file cabinet, new label:table
# frame_001470,line_54, old label:ceiling, new label:unlabeled
# frame_001470,line_56, old label:ceiling, new label:unlabeled
# frame_001470,line_57, old label:ceiling, new label:unlabeled
# frame_001470,line_58, old label:ceiling, new label:unlabeled
# processing frame_001550
# frame_001550,line_1, old label:window, new label:unlabeled
# frame_001550,line_3, old label:file cabinet, new label:table
# frame_001550,line_5, old label:blinds, new label:unlabeled
# frame_001550,line_6, old label:blinds, new label:unlabeled
# frame_001550,line_7, old label:wall, new label:unlabeled
# frame_001550,line_8, old label:window, new label:unlabeled
# frame_001550,line_9, old label:window, new label:unlabeled
# frame_001550,line_10, old label:window, new label:unlabeled
# frame_001550,line_11, old label:window sill, new label:unlabeled
# frame_001550,line_12, old label:monitor, new label:computer tower
# frame_001550,line_17, old label:window sill, new label:unlabeled
# frame_001550,line_18, old label:office chair, new label:unlabeled
# frame_001550,line_24, old label:table, new label:unlabeled
# frame_001550,line_26, old label:heater, new label:unlabeled
# frame_001550,line_41, old label:office chair, new label:unlabeled
# frame_001550,line_45, old label:file cabinet, new label:table
# frame_001550,line_46, old label:table, new label:unlabeled
# frame_001550,line_47, old label:office chair, new label:unlabeled
# frame_001550,line_49, old label:monitor, new label:computer tower
# frame_001550,line_50, old label:office chair, new label:unlabeled
# frame_001550,line_51, old label:floor, new label:table
# processing frame_001630
# frame_001630,line_6, old label:monitor, new label:file cabinet
# frame_001630,line_8, old label:monitor, new label:file cabinet
# frame_001630,line_10, old label:window sill, new label:unlabeled
# frame_001630,line_12, old label:window sill, new label:unlabeled
# frame_001630,line_13, old label:window sill, new label:unlabeled
# frame_001630,line_17, old label:heater, new label:unlabeled
# frame_001630,line_18, old label:monitor, new label:unlabeled
# frame_001630,line_20, old label:window, new label:unlabeled
# frame_001630,line_21, old label:window, new label:unlabeled
# frame_001630,line_24, old label:window, new label:unlabeled
# frame_001630,line_25, old label:monitor, new label:file cabinet
# frame_001630,line_31, old label:table, new label:monitor
# frame_001630,line_34, old label:table, new label:unlabeled
# frame_001630,line_41, old label:whiteboard, new label:unlabeled
# frame_001630,line_43, old label:table, new label:unlabeled
# processing frame_001710
# frame_001710,line_5, old label:window, new label:unlabeled
# frame_001710,line_7, old label:window sill, new label:file cabinet
# frame_001710,line_10, old label:window, new label:unlabeled
# frame_001710,line_12, old label:wall, new label:file cabinet
# frame_001710,line_13, old label:table, new label:unlabeled
# frame_001710,line_14, old label:window, new label:unlabeled
# frame_001710,line_16, old label:window, new label:unlabeled
# frame_001710,line_17, old label:window sill, new label:file cabinet
# frame_001710,line_19, old label:window sill, new label:file cabinet
# frame_001710,line_20, old label:laptop stand, new label:laptop
# frame_001710,line_23, old label:wall, new label:file cabinet
# frame_001710,line_25, old label:window sill, new label:file cabinet
# frame_001710,line_26, old label:table, new label:keyboard
# frame_001710,line_27, old label:file cabinet, new label:table
# frame_001710,line_28, old label:window, new label:unlabeled
# processing frame_001790
# frame_001790,line_2, old label:window sill, new label:unlabeled
# frame_001790,line_3, old label:window, new label:unlabeled
# frame_001790,line_4, old label:window, new label:unlabeled
# frame_001790,line_7, old label:window sill, new label:unlabeled
# frame_001790,line_8, old label:window sill, new label:unlabeled
# frame_001790,line_9, old label:window sill, new label:unlabeled
# frame_001790,line_10, old label:window sill, new label:unlabeled
# frame_001790,line_11, old label:window, new label:unlabeled
# frame_001790,line_12, old label:laptop stand, new label:laptop
# frame_001790,line_14, old label:window, new label:unlabeled
# frame_001790,line_15, old label:window, new label:unlabeled
# frame_001790,line_16, old label:window sill, new label:unlabeled
# frame_001790,line_17, old label:window sill, new label:unlabeled
# frame_001790,line_18, old label:wall, new label:unlabeled
# frame_001790,line_20, old label:wall, new label:unlabeled
# frame_001790,line_21, old label:window sill, new label:unlabeled
# frame_001790,line_22, old label:window, new label:unlabeled
# frame_001790,line_23, old label:laptop stand, new label:laptop
# frame_001790,line_24, old label:window, new label:unlabeled
# frame_001790,line_25, old label:window sill, new label:unlabeled
# frame_001790,line_26, old label:laptop, new label:unlabeled
# frame_001790,line_29, old label:laptop stand, new label:laptop
# frame_001790,line_30, old label:window sill, new label:unlabeled
# processing frame_001870
# frame_001870,line_6, old label:keyboard, new label:table
# frame_001870,line_12, old label:monitor, new label:computer tower
# frame_001870,line_13, old label:wall, new label:unlabeled
# frame_001870,line_15, old label:wall, new label:unlabeled
# frame_001870,line_16, old label:wall, new label:unlabeled
# frame_001870,line_17, old label:wall, new label:unlabeled
# frame_001870,line_18, old label:office chair, new label:table
# frame_001870,line_19, old label:wall, new label:unlabeled
# frame_001870,line_22, old label:monitor, new label:computer tower
# frame_001870,line_25, old label:monitor, new label:computer tower
# frame_001870,line_26, old label:laptop stand, new label:laptop
# frame_001870,line_27, old label:wall, new label:unlabeled
# processing frame_001950
# frame_001950,line_0, old label:storage cabinet, new label:door
# frame_001950,line_2, old label:storage cabinet, new label:door
# frame_001950,line_3, old label:door, new label:unlabeled
# frame_001950,line_4, old label:storage cabinet, new label:door
# frame_001950,line_5, old label:coat hanger, new label:unlabeled
# frame_001950,line_6, old label:coat hanger, new label:unlabeled
# frame_001950,line_9, old label:storage cabinet, new label:door
# processing frame_002030
# frame_002030,line_2, old label:whiteboard, new label:wall
# frame_002030,line_3, old label:storage cabinet, new label:wall
# frame_002030,line_4, old label:storage cabinet, new label:door
# frame_002030,line_5, old label:ceiling lamp, new label:blinds
# frame_002030,line_12, old label:pipe, new label:unlabeled
# processing frame_002110
# frame_002110,line_3, old label:whiteboard, new label:unlabeled
# frame_002110,line_6, old label:floor, new label:unlabeled
# frame_002110,line_9, old label:whiteboard, new label:wall
# frame_002110,line_14, old label:file cabinet, new label:table
# frame_002110,line_15, old label:file cabinet, new label:table
# processing frame_002190
# processing frame_002270
# frame_002270,line_2, old label:wall, new label:unlabeled
# frame_002270,line_3, old label:window, new label:unlabeled
# frame_002270,line_4, old label:heater, new label:unlabeled
# frame_002270,line_5, old label:file cabinet, new label:table
# frame_002270,line_6, old label:floor, new label:table
# frame_002270,line_7, old label:window sill, new label:unlabeled
# frame_002270,line_8, old label:file cabinet, new label:table
# frame_002270,line_9, old label:file cabinet, new label:table
# frame_002270,line_10, old label:window, new label:unlabeled
# frame_002270,line_12, old label:window sill, new label:unlabeled
# frame_002270,line_13, old label:file cabinet, new label:table
# frame_002270,line_14, old label:window, new label:unlabeled
# frame_002270,line_15, old label:file cabinet, new label:table
# frame_002270,line_16, old label:file cabinet, new label:table
# frame_002270,line_17, old label:file cabinet, new label:unlabeled
# frame_002270,line_19, old label:window, new label:unlabeled
# frame_002270,line_21, old label:window, new label:unlabeled
# frame_002270,line_22, old label:wall, new label:unlabeled
# frame_002270,line_23, old label:monitor, new label:computer tower
# frame_002270,line_24, old label:file cabinet, new label:table
# frame_002270,line_25, old label:file cabinet, new label:table
# frame_002270,line_26, old label:file cabinet, new label:table
# frame_002270,line_28, old label:file cabinet, new label:table
# frame_002270,line_30, old label:monitor, new label:computer tower
# frame_002270,line_31, old label:file cabinet, new label:table
# processing frame_002420
# frame_002420,line_1, old label:pipe, new label:ceiling
# frame_002420,line_2, old label:door, new label:window
# frame_002420,line_4, old label:ceiling lamp, new label:ceiling
# frame_002420,line_7, old label:ceiling lamp, new label:ceiling
# frame_002420,line_8, old label:pipe, new label:unlabeled
# processing frame_002500
# frame_002500,line_0, old label:storage cabinet, new label:door
# frame_002500,line_1, old label:storage cabinet, new label:door
# frame_002500,line_2, old label:wall, new label:unlabeled
# frame_002500,line_5, old label:wall, new label:unlabeled
# frame_002500,line_6, old label:wall, new label:unlabeled
# frame_002500,line_7, old label:wall, new label:unlabeled
# frame_002500,line_8, old label:wall, new label:unlabeled
# frame_002500,line_9, old label:wall, new label:unlabeled
# processing frame_002580
# frame_002580,line_0, old label:storage cabinet, new label:unlabeled
# frame_002580,line_2, old label:storage cabinet, new label:unlabeled
# frame_002580,line_6, old label:monitor, new label:unlabeled
# frame_002580,line_11, old label:box, new label:unlabeled
# frame_002580,line_13, old label:floor, new label:unlabeled
# frame_002580,line_15, old label:storage cabinet, new label:unlabeled
# frame_002580,line_17, old label:door, new label:unlabeled
# frame_002580,line_18, old label:storage cabinet, new label:office chair
# frame_002580,line_19, old label:monitor, new label:unlabeled
# frame_002580,line_20, old label:box, new label:unlabeled
# frame_002580,line_22, old label:storage cabinet, new label:unlabeled
# processing frame_002660
# frame_002660,line_0, old label:window sill, new label:unlabeled
# frame_002660,line_4, old label:window sill, new label:unlabeled
# frame_002660,line_5, old label:wall, new label:unlabeled
# frame_002660,line_6, old label:window sill, new label:unlabeled
# frame_002660,line_7, old label:wall, new label:unlabeled
# frame_002660,line_8, old label:table, new label:unlabeled
# frame_002660,line_11, old label:table, new label:unlabeled
# frame_002660,line_12, old label:window, new label:unlabeled
# frame_002660,line_15, old label:table, new label:unlabeled
# frame_002660,line_16, old label:window sill, new label:unlabeled
# frame_002660,line_17, old label:table, new label:unlabeled
# frame_002660,line_22, old label:table, new label:unlabeled
# frame_002660,line_25, old label:laptop stand, new label:laptop
# frame_002660,line_26, old label:table, new label:keyboard
# frame_002660,line_28, old label:window sill, new label:unlabeled
# frame_002660,line_30, old label:table, new label:unlabeled
# processing frame_002760
# frame_002760,line_4, old label:monitor, new label:unlabeled
# frame_002760,line_12, old label:keyboard, new label:unlabeled
# frame_002760,line_14, old label:file cabinet, new label:unlabeled
# frame_002760,line_15, old label:wall, new label:unlabeled
# frame_002760,line_20, old label:floor, new label:unlabeled
# frame_002760,line_23, old label:file cabinet, new label:table
# frame_002760,line_26, old label:table, new label:unlabeled
# frame_002760,line_27, old label:box, new label:unlabeled
# processing frame_002840
# frame_002840,line_2, old label:table, new label:unlabeled
# frame_002840,line_3, old label:monitor, new label:computer tower
# frame_002840,line_4, old label:table, new label:unlabeled
# frame_002840,line_10, old label:wall, new label:unlabeled
# frame_002840,line_11, old label:laptop stand, new label:laptop
# frame_002840,line_12, old label:laptop stand, new label:laptop
# frame_002840,line_13, old label:laptop stand, new label:laptop
# frame_002840,line_17, old label:window, new label:unlabeled
# frame_002840,line_18, old label:window sill, new label:unlabeled
# frame_002840,line_23, old label:window sill, new label:unlabeled
# frame_002840,line_26, old label:wall, new label:unlabeled
# frame_002840,line_28, old label:floor, new label:unlabeled
# frame_002840,line_29, old label:window sill, new label:unlabeled
# frame_002840,line_31, old label:floor, new label:office chair
# frame_002840,line_33, old label:window, new label:unlabeled
# frame_002840,line_34, old label:laptop stand, new label:unlabeled
# frame_002840,line_35, old label:monitor, new label:computer tower
# processing frame_002920
# frame_002920,line_9, old label:table, new label:unlabeled
# frame_002920,line_10, old label:window sill, new label:unlabeled
# frame_002920,line_11, old label:window sill, new label:unlabeled
# frame_002920,line_16, old label:laptop stand, new label:computer tower
# frame_002920,line_19, old label:office chair, new label:unlabeled
# frame_002920,line_21, old label:laptop stand, new label:unlabeled
# frame_002920,line_26, old label:keyboard, new label:table
# frame_002920,line_32, old label:wall, new label:unlabeled
# frame_002920,line_35, old label:table, new label:unlabeled
# frame_002920,line_37, old label:laptop stand, new label:laptop
# processing frame_003000
# frame_003000,line_2, old label:wall, new label:unlabeled
# frame_003000,line_4, old label:table, new label:keyboard
# frame_003000,line_5, old label:wall, new label:unlabeled
# frame_003000,line_6, old label:window sill, new label:unlabeled
# frame_003000,line_8, old label:floor, new label:file cabinet
# frame_003000,line_15, old label:wall, new label:unlabeled
# frame_003000,line_17, old label:laptop stand, new label:laptop
# frame_003000,line_22, old label:floor, new label:office chair
# frame_003000,line_26, old label:computer tower, new label:unlabeled
# frame_003000,line_27, old label:laptop stand, new label:laptop
# frame_003000,line_29, old label:office chair, new label:unlabeled
# frame_003000,line_31, old label:table, new label:unlabeled
# frame_003000,line_39, old label:office chair, new label:unlabeled
# frame_003000,line_40, old label:laptop, new label:unlabeled
# processing frame_003080
# frame_003080,line_0, old label:wall, new label:unlabeled
# frame_003080,line_1, old label:pipe, new label:unlabeled
# frame_003080,line_3, old label:window sill, new label:unlabeled
# frame_003080,line_6, old label:box, new label:file cabinet
# frame_003080,line_7, old label:table, new label:keyboard
# frame_003080,line_8, old label:wall, new label:unlabeled
# frame_003080,line_10, old label:box, new label:file cabinet
# frame_003080,line_11, old label:box, new label:file cabinet
# frame_003080,line_13, old label:window sill, new label:unlabeled
# frame_003080,line_16, old label:pipe, new label:unlabeled
# frame_003080,line_19, old label:pipe, new label:unlabeled
# frame_003080,line_20, old label:box, new label:file cabinet
# frame_003080,line_21, old label:wall, new label:unlabeled
# frame_003080,line_25, old label:keyboard, new label:table
# processing frame_003160
# frame_003160,line_0, old label:floor, new label:door
# frame_003160,line_1, old label:sofa, new label:sofa cushion
# frame_003160,line_7, old label:sofa, new label:sofa cushion
# frame_003160,line_15, old label:table, new label:wall
# processing frame_003240
# frame_003240,line_5, old label:wall, new label:unlabeled
# frame_003240,line_6, old label:sofa, new label:wall
# processing frame_003380
# frame_003380,line_2, old label:wall, new label:unlabeled
# frame_003380,line_4, old label:table, new label:keyboard
# frame_003380,line_5, old label:file cabinet, new label:table
# frame_003380,line_6, old label:window sill, new label:unlabeled
# frame_003380,line_7, old label:box, new label:file cabinet
# frame_003380,line_9, old label:heater, new label:unlabeled
# frame_003380,line_10, old label:floor, new label:file cabinet
# frame_003380,line_12, old label:box, new label:file cabinet
# frame_003380,line_14, old label:wall, new label:unlabeled
# frame_003380,line_19, old label:laptop, new label:unlabeled
# frame_003380,line_20, old label:pipe, new label:unlabeled
# frame_003380,line_23, old label:box, new label:file cabinet
# frame_003380,line_24, old label:pipe, new label:unlabeled
# frame_003380,line_26, old label:box, new label:file cabinet
# processing frame_003500
# frame_003500,line_1, old label:whiteboard, new label:wall
# frame_003500,line_2, old label:ceiling, new label:unlabeled
# frame_003500,line_5, old label:storage cabinet, new label:unlabeled
# frame_003500,line_6, old label:ceiling, new label:unlabeled
# frame_003500,line_7, old label:monitor, new label:file cabinet
# frame_003500,line_8, old label:blinds, new label:door
# frame_003500,line_10, old label:ceiling, new label:unlabeled
# frame_003500,line_11, old label:ceiling, new label:unlabeled
# frame_003500,line_12, old label:ceiling lamp, new label:unlabeled
# frame_003500,line_13, old label:ceiling lamp, new label:unlabeled
# frame_003500,line_14, old label:ceiling lamp, new label:unlabeled
# frame_003500,line_15, old label:ceiling, new label:unlabeled
# frame_003500,line_16, old label:ceiling, new label:unlabeled
# frame_003500,line_17, old label:ceiling, new label:unlabeled
# frame_003500,line_18, old label:monitor, new label:file cabinet
# processing frame_003580
# frame_003580,line_1, old label:storage cabinet, new label:door
# frame_003580,line_2, old label:ceiling lamp, new label:blinds
# frame_003580,line_3, old label:ceiling lamp, new label:blinds
# frame_003580,line_4, old label:ceiling, new label:unlabeled
# frame_003580,line_5, old label:pipe, new label:unlabeled
# frame_003580,line_7, old label:storage cabinet, new label:unlabeled
# frame_003580,line_9, old label:storage cabinet, new label:unlabeled
# frame_003580,line_10, old label:ceiling lamp, new label:window
# frame_003580,line_11, old label:whiteboard, new label:unlabeled
# processing frame_003900
# frame_003900,line_0, old label:door, new label:unlabeled
# frame_003900,line_1, old label:door, new label:unlabeled
# frame_003900,line_3, old label:door, new label:unlabeled
# frame_003900,line_5, old label:wall, new label:unlabeled
# processing frame_003980
# frame_003980,line_0, old label:door, new label:unlabeled
# frame_003980,line_1, old label:door, new label:unlabeled
# frame_003980,line_2, old label:sofa, new label:unlabeled
# frame_003980,line_5, old label:sofa, new label:sofa cushion
# frame_003980,line_8, old label:sofa, new label:sofa cushion
# processing frame_004060
# frame_004060,line_0, old label:door, new label:unlabeled
# frame_004060,line_1, old label:door, new label:unlabeled
# frame_004060,line_2, old label:door, new label:unlabeled
# frame_004060,line_3, old label:sofa, new label:sofa cushion
# frame_004060,line_5, old label:wall, new label:unlabeled
# frame_004060,line_6, old label:wall, new label:unlabeled
# frame_004060,line_7, old label:sofa, new label:sofa cushion
# frame_004060,line_8, old label:wall, new label:unlabeled
# frame_004060,line_9, old label:wall, new label:unlabeled
# frame_004060,line_10, old label:sofa, new label:sofa cushion
# frame_004060,line_11, old label:wall, new label:unlabeled
# frame_004060,line_12, old label:sofa, new label:sofa cushion
# frame_004060,line_13, old label:wall, new label:unlabeled
# frame_004060,line_14, old label:wall, new label:unlabeled
# frame_004060,line_15, old label:wall, new label:unlabeled
# frame_004060,line_16, old label:wall, new label:unlabeled
# frame_004060,line_17, old label:wall, new label:unlabeled
# frame_004060,line_18, old label:wall, new label:unlabeled
# frame_004060,line_19, old label:wall, new label:unlabeled
# frame_004060,line_20, old label:wall, new label:unlabeled
# frame_004060,line_21, old label:sofa, new label:sofa cushion
# frame_004060,line_22, old label:sofa, new label:sofa cushion
# frame_004060,line_23, old label:wall, new label:unlabeled
# frame_004060,line_24, old label:wall, new label:unlabeled
# frame_004060,line_25, old label:wall, new label:unlabeled
# frame_004060,line_26, old label:wall, new label:unlabeled
# frame_004060,line_27, old label:wall, new label:unlabeled
# frame_004060,line_28, old label:wall, new label:unlabeled
# frame_004060,line_29, old label:wall, new label:unlabeled
# frame_004060,line_30, old label:wall, new label:unlabeled
# frame_004060,line_31, old label:sofa, new label:sofa cushion
# frame_004060,line_32, old label:wall, new label:unlabeled
# frame_004060,line_33, old label:wall, new label:unlabeled
# frame_004060,line_34, old label:wall, new label:unlabeled
# frame_004060,line_35, old label:wall, new label:unlabeled
# frame_004060,line_36, old label:wall, new label:unlabeled
# processing frame_004140
# frame_004140,line_0, old label:floor, new label:unlabeled
# frame_004140,line_7, old label:wall, new label:unlabeled
# processing frame_004780
# frame_004780,line_5, old label:ceiling lamp, new label:unlabeled
# frame_004780,line_7, old label:sofa cushion, new label:unlabeled
# processing frame_004860
# frame_004860,line_0, old label:door, new label:unlabeled
# frame_004860,line_1, old label:ceiling lamp, new label:unlabeled
# frame_004860,line_4, old label:door, new label:unlabeled
# frame_004860,line_5, old label:pipe, new label:unlabeled
# frame_004860,line_6, old label:sofa, new label:sofa cushion
# frame_004860,line_7, old label:door, new label:unlabeled
# frame_004860,line_9, old label:sofa, new label:sofa cushion
# processing frame_005060
# frame_005060,line_4, old label:table, new label:keyboard
# frame_005060,line_6, old label:window, new label:unlabeled
# frame_005060,line_7, old label:monitor, new label:unlabeled
# frame_005060,line_8, old label:monitor, new label:computer tower
# frame_005060,line_10, old label:file cabinet, new label:table
# frame_005060,line_12, old label:window, new label:unlabeled
# frame_005060,line_13, old label:window, new label:unlabeled
# frame_005060,line_16, old label:window, new label:unlabeled
# frame_005060,line_17, old label:window, new label:unlabeled
# frame_005060,line_18, old label:window, new label:unlabeled
# frame_005060,line_19, old label:blinds, new label:unlabeled
# frame_005060,line_21, old label:blinds, new label:unlabeled
# frame_005060,line_24, old label:table, new label:unlabeled
# frame_005060,line_26, old label:window, new label:unlabeled
# frame_005060,line_31, old label:monitor, new label:file cabinet
# frame_005060,line_33, old label:window, new label:unlabeled
# frame_005060,line_36, old label:monitor, new label:unlabeled
# frame_005060,line_37, old label:table, new label:monitor
# frame_005060,line_39, old label:monitor, new label:unlabeled
# frame_005060,line_40, old label:monitor, new label:unlabeled
# frame_005060,line_41, old label:table, new label:unlabeled
# frame_005060,line_42, old label:table, new label:unlabeled
# frame_005060,line_43, old label:window, new label:unlabeled
# frame_005060,line_44, old label:table, new label:unlabeled
# frame_005060,line_45, old label:table, new label:unlabeled
# frame_005060,line_46, old label:table, new label:unlabeled
# frame_005060,line_47, old label:monitor, new label:computer tower
# frame_005060,line_48, old label:table, new label:unlabeled
# processing frame_005140
# frame_005140,line_3, old label:window, new label:unlabeled
# frame_005140,line_4, old label:window, new label:unlabeled
# frame_005140,line_7, old label:window, new label:unlabeled
# frame_005140,line_11, old label:window, new label:unlabeled
# frame_005140,line_12, old label:window, new label:unlabeled
# frame_005140,line_13, old label:window, new label:unlabeled
# frame_005140,line_14, old label:window, new label:unlabeled
# frame_005140,line_15, old label:window, new label:unlabeled
# frame_005140,line_17, old label:window, new label:unlabeled
# frame_005140,line_18, old label:window, new label:unlabeled
# frame_005140,line_20, old label:table, new label:keyboard
# frame_005140,line_29, old label:window, new label:unlabeled
# frame_005140,line_30, old label:monitor, new label:unlabeled
# frame_005140,line_31, old label:blinds, new label:unlabeled
# frame_005140,line_32, old label:table, new label:unlabeled
# frame_005140,line_34, old label:table, new label:unlabeled
# frame_005140,line_35, old label:window, new label:unlabeled
# frame_005140,line_37, old label:monitor, new label:unlabeled
# frame_005140,line_38, old label:window sill, new label:telephone
# processing frame_005220
# frame_005220,line_2, old label:table, new label:keyboard
# frame_005220,line_3, old label:monitor, new label:unlabeled
# frame_005220,line_9, old label:wall, new label:unlabeled
# frame_005220,line_13, old label:table, new label:unlabeled
# frame_005220,line_14, old label:wall, new label:unlabeled
# frame_005220,line_15, old label:table, new label:unlabeled
# frame_005220,line_19, old label:keyboard, new label:unlabeled
# frame_005220,line_20, old label:monitor, new label:unlabeled
# frame_005220,line_22, old label:file cabinet, new label:table
# frame_005220,line_24, old label:table, new label:unlabeled
# processing frame_005300
# frame_005300,line_2, old label:table, new label:keyboard
# frame_005300,line_3, old label:box, new label:unlabeled
# frame_005300,line_4, old label:door, new label:unlabeled
# frame_005300,line_8, old label:file cabinet, new label:table
# frame_005300,line_9, old label:office chair, new label:unlabeled
# frame_005300,line_10, old label:floor, new label:office chair
# frame_005300,line_12, old label:table, new label:unlabeled
# frame_005300,line_13, old label:file cabinet, new label:table
# frame_005300,line_15, old label:table, new label:unlabeled
# frame_005300,line_18, old label:table, new label:unlabeled
# processing frame_005380
# frame_005380,line_2, old label:file cabinet, new label:table
# frame_005380,line_5, old label:pipe, new label:unlabeled
# frame_005380,line_6, old label:file cabinet, new label:table
# frame_005380,line_8, old label:file cabinet, new label:table
# frame_005380,line_9, old label:file cabinet, new label:table
# frame_005380,line_16, old label:file cabinet, new label:table
# frame_005380,line_17, old label:floor, new label:office chair
# frame_005380,line_18, old label:floor, new label:box
# frame_005380,line_19, old label:file cabinet, new label:table
# frame_005380,line_26, old label:wall, new label:floor
# frame_005380,line_27, old label:file cabinet, new label:table
# frame_005380,line_28, old label:file cabinet, new label:table
# processing frame_005460
# frame_005460,line_10, old label:floor, new label:box
# processing frame_005540
# frame_005540,line_4, old label:heater, new label:unlabeled
# frame_005540,line_6, old label:file cabinet, new label:table
# frame_005540,line_7, old label:floor, new label:box
# frame_005540,line_9, old label:file cabinet, new label:floor
# frame_005540,line_10, old label:file cabinet, new label:table
# frame_005540,line_12, old label:file cabinet, new label:table
# frame_005540,line_15, old label:wall, new label:unlabeled
# frame_005540,line_18, old label:file cabinet, new label:table
# frame_005540,line_19, old label:file cabinet, new label:floor
# frame_005540,line_21, old label:file cabinet, new label:table
# frame_005540,line_24, old label:pipe, new label:unlabeled
# frame_005540,line_26, old label:file cabinet, new label:table
# frame_005540,line_31, old label:monitor, new label:unlabeled
# processing frame_005620
# frame_005620,line_2, old label:file cabinet, new label:floor
# frame_005620,line_3, old label:heater, new label:unlabeled
# frame_005620,line_5, old label:floor, new label:unlabeled
# frame_005620,line_6, old label:file cabinet, new label:floor
# frame_005620,line_14, old label:floor, new label:unlabeled
# frame_005620,line_21, old label:wall, new label:unlabeled
# frame_005620,line_22, old label:heater, new label:unlabeled
# frame_005620,line_24, old label:box, new label:file cabinet
# frame_005620,line_26, old label:floor, new label:unlabeled
# processing frame_005700
# frame_005700,line_2, old label:file cabinet, new label:table
# frame_005700,line_3, old label:file cabinet, new label:table
# frame_005700,line_4, old label:file cabinet, new label:computer tower
# frame_005700,line_6, old label:file cabinet, new label:table
# frame_005700,line_7, old label:table, new label:keyboard
# frame_005700,line_13, old label:floor, new label:table
# frame_005700,line_18, old label:office chair, new label:table
# frame_005700,line_19, old label:wall, new label:unlabeled
# frame_005700,line_20, old label:monitor, new label:unlabeled
# frame_005700,line_26, old label:file cabinet, new label:unlabeled
# frame_005700,line_27, old label:box, new label:table
# frame_005700,line_30, old label:monitor, new label:unlabeled
# frame_005700,line_31, old label:box, new label:table
# processing frame_005780
# frame_005780,line_6, old label:door, new label:unlabeled
# frame_005780,line_7, old label:wall, new label:unlabeled
# frame_005780,line_11, old label:table, new label:keyboard
# frame_005780,line_12, old label:door, new label:unlabeled
# frame_005780,line_14, old label:table, new label:unlabeled
# frame_005780,line_15, old label:table, new label:unlabeled
# frame_005780,line_16, old label:blinds, new label:unlabeled
# frame_005780,line_17, old label:laptop stand, new label:unlabeled
# frame_005780,line_19, old label:table, new label:unlabeled
# frame_005780,line_22, old label:office chair, new label:unlabeled
# frame_005780,line_23, old label:table, new label:monitor
# frame_005780,line_24, old label:table, new label:unlabeled
# processing frame_005860
# frame_005860,line_6, old label:table, new label:keyboard
# frame_005860,line_9, old label:wall, new label:file cabinet
# frame_005860,line_10, old label:door, new label:unlabeled
# frame_005860,line_11, old label:door, new label:unlabeled
# frame_005860,line_12, old label:wall, new label:unlabeled
# frame_005860,line_13, old label:door, new label:unlabeled
# frame_005860,line_14, old label:door, new label:unlabeled
# frame_005860,line_15, old label:blinds, new label:unlabeled
# frame_005860,line_16, old label:monitor, new label:unlabeled
# frame_005860,line_19, old label:blinds, new label:unlabeled
# frame_005860,line_20, old label:window sill, new label:file cabinet
# frame_005860,line_23, old label:laptop stand, new label:laptop
# frame_005860,line_24, old label:laptop stand, new label:laptop
# frame_005860,line_25, old label:door, new label:unlabeled
# frame_005860,line_26, old label:window sill, new label:file cabinet
# frame_005860,line_27, old label:table, new label:laptop stand
# frame_005860,line_29, old label:table, new label:unlabeled
# frame_005860,line_31, old label:table, new label:laptop
# frame_005860,line_32, old label:table, new label:unlabeled
# frame_005860,line_33, old label:window sill, new label:unlabeled
# processing frame_005940
# frame_005940,line_3, old label:wall, new label:unlabeled
# frame_005940,line_4, old label:wall, new label:window
# frame_005940,line_7, old label:wall, new label:window
# frame_005940,line_9, old label:door, new label:wall
# frame_005940,line_10, old label:blinds, new label:wall
# frame_005940,line_11, old label:door, new label:wall
# frame_005940,line_13, old label:window sill, new label:unlabeled
# frame_005940,line_16, old label:window sill, new label:unlabeled
# frame_005940,line_17, old label:laptop stand, new label:laptop
# frame_005940,line_19, old label:wall, new label:unlabeled
# frame_005940,line_21, old label:wall, new label:unlabeled
# frame_005940,line_22, old label:office chair, new label:unlabeled
# frame_005940,line_25, old label:door, new label:wall
# frame_005940,line_26, old label:laptop stand, new label:table
# frame_005940,line_27, old label:table, new label:unlabeled
# frame_005940,line_28, old label:wall, new label:unlabeled
# frame_005940,line_29, old label:window sill, new label:unlabeled
# frame_005940,line_33, old label:table, new label:unlabeled
# processing frame_006020
# frame_006020,line_0, old label:wall, new label:computer tower
# frame_006020,line_9, old label:floor, new label:unlabeled
# frame_006020,line_16, old label:floor, new label:table
# frame_006020,line_21, old label:wall, new label:unlabeled
# frame_006020,line_22, old label:heater, new label:unlabeled
# frame_006020,line_40, old label:floor, new label:unlabeled
# frame_006020,line_48, old label:file cabinet, new label:unlabeled
# frame_006020,line_51, old label:file cabinet, new label:office chair
# processing frame_006100
# frame_006100,line_27, old label:table, new label:unlabeled
# frame_006100,line_28, old label:table, new label:unlabeled
# frame_006100,line_30, old label:laptop stand, new label:laptop
# frame_006100,line_33, old label:table, new label:unlabeled
# frame_006100,line_35, old label:table, new label:unlabeled
# processing frame_006180
# frame_006180,line_3, old label:table, new label:keyboard
# frame_006180,line_5, old label:window sill, new label:unlabeled
# frame_006180,line_6, old label:window, new label:unlabeled
# frame_006180,line_10, old label:window sill, new label:unlabeled
# frame_006180,line_11, old label:laptop stand, new label:laptop
# frame_006180,line_16, old label:table, new label:monitor
# frame_006180,line_17, old label:table, new label:unlabeled
# frame_006180,line_21, old label:office chair, new label:unlabeled
# frame_006180,line_23, old label:table, new label:laptop
# frame_006180,line_25, old label:window sill, new label:unlabeled
# frame_006180,line_27, old label:table, new label:unlabeled
# frame_006180,line_29, old label:table, new label:unlabeled
# frame_006180,line_30, old label:table, new label:unlabeled
# processing frame_006260
# frame_006260,line_1, old label:wall, new label:unlabeled
# frame_006260,line_4, old label:wall, new label:unlabeled
# frame_006260,line_10, old label:heater, new label:unlabeled
# frame_006260,line_12, old label:heater, new label:unlabeled
# frame_006260,line_13, old label:pipe, new label:unlabeled
# frame_006260,line_14, old label:pipe, new label:unlabeled
# frame_006260,line_20, old label:computer tower, new label:floor
# frame_006260,line_21, old label:window sill, new label:unlabeled
# frame_006260,line_22, old label:pipe, new label:unlabeled
# frame_006260,line_23, old label:pipe, new label:unlabeled
# frame_006260,line_25, old label:window sill, new label:unlabeled
# frame_006260,line_28, old label:wall, new label:unlabeled
# frame_006260,line_30, old label:office chair, new label:unlabeled
# frame_006260,line_32, old label:pipe, new label:unlabeled
# processing frame_006340
# frame_006340,line_6, old label:table, new label:keyboard
# frame_006340,line_9, old label:office chair, new label:table
# frame_006340,line_17, old label:laptop stand, new label:unlabeled
# frame_006340,line_18, old label:office chair, new label:monitor
# frame_006340,line_20, old label:laptop stand, new label:unlabeled
# frame_006340,line_23, old label:table, new label:unlabeled
# frame_006340,line_24, old label:monitor, new label:computer tower
# frame_006340,line_25, old label:table, new label:unlabeled
# processing frame_006420
# frame_006420,line_0, old label:wall, new label:unlabeled
# frame_006420,line_1, old label:window sill, new label:unlabeled
# frame_006420,line_3, old label:window sill, new label:unlabeled
# frame_006420,line_4, old label:wall, new label:unlabeled
# frame_006420,line_7, old label:heater, new label:unlabeled
# frame_006420,line_9, old label:floor, new label:unlabeled
# frame_006420,line_10, old label:pipe, new label:unlabeled
# frame_006420,line_11, old label:computer tower, new label:unlabeled
# frame_006420,line_13, old label:window, new label:unlabeled
# frame_006420,line_15, old label:window sill, new label:unlabeled
# frame_006420,line_16, old label:pipe, new label:unlabeled
# frame_006420,line_18, old label:window sill, new label:unlabeled
# frame_006420,line_22, old label:office chair, new label:unlabeled
# frame_006420,line_24, old label:office chair, new label:unlabeled
# frame_006420,line_26, old label:wall, new label:unlabeled
# frame_006420,line_27, old label:office chair, new label:unlabeled
# frame_006420,line_29, old label:window sill, new label:unlabeled
# processing frame_006500
# frame_006500,line_0, old label:window sill, new label:table
# frame_006500,line_1, old label:wall, new label:table
# frame_006500,line_2, old label:heater, new label:table
# frame_006500,line_3, old label:wall, new label:table
# frame_006500,line_4, old label:wall, new label:table
# frame_006500,line_6, old label:heater, new label:table
# frame_006500,line_9, old label:pipe, new label:table
# frame_006500,line_12, old label:window sill, new label:unlabeled
# frame_006500,line_13, old label:table, new label:unlabeled
# frame_006500,line_14, old label:window sill, new label:unlabeled
# frame_006500,line_15, old label:window sill, new label:table
# frame_006500,line_17, old label:wall, new label:table
# frame_006500,line_18, old label:pipe, new label:table
# frame_006500,line_22, old label:window sill, new label:table
# frame_006500,line_23, old label:window sill, new label:table
# frame_006500,line_24, old label:laptop, new label:keyboard
# frame_006500,line_25, old label:window sill, new label:table
# frame_006500,line_26, old label:office chair, new label:floor
# frame_006500,line_27, old label:office chair, new label:unlabeled
# frame_006500,line_28, old label:table, new label:unlabeled
# frame_006500,line_29, old label:window sill, new label:table
# frame_006500,line_30, old label:window sill, new label:table
# frame_006500,line_32, old label:window sill, new label:table
# frame_006500,line_35, old label:window sill, new label:unlabeled
# processing frame_006580
# frame_006580,line_0, old label:wall, new label:file cabinet
# frame_006580,line_1, old label:wall, new label:file cabinet
# frame_006580,line_2, old label:window sill, new label:file cabinet
# frame_006580,line_3, old label:heater, new label:file cabinet
# frame_006580,line_4, old label:window sill, new label:window
# frame_006580,line_5, old label:window sill, new label:file cabinet
# frame_006580,line_7, old label:wall, new label:file cabinet
# frame_006580,line_12, old label:window sill, new label:window
# frame_006580,line_14, old label:laptop, new label:unlabeled
# frame_006580,line_19, old label:window sill, new label:window
# frame_006580,line_20, old label:window sill, new label:window
# frame_006580,line_21, old label:wall, new label:file cabinet
# frame_006580,line_22, old label:pipe, new label:file cabinet
# frame_006580,line_25, old label:office chair, new label:floor
# frame_006580,line_26, old label:pipe, new label:file cabinet
# frame_006580,line_29, old label:laptop stand, new label:laptop
# frame_006580,line_30, old label:table, new label:laptop
# frame_006580,line_32, old label:window sill, new label:file cabinet
# frame_006580,line_33, old label:office chair, new label:table
# frame_006580,line_34, old label:window sill, new label:unlabeled
# frame_006580,line_35, old label:window sill, new label:window
# frame_006580,line_36, old label:window sill, new label:file cabinet
# frame_006580,line_38, old label:heater, new label:file cabinet
# frame_006580,line_39, old label:wall, new label:file cabinet
# frame_006580,line_40, old label:wall, new label:file cabinet
# frame_006580,line_41, old label:window sill, new label:unlabeled
# frame_006580,line_42, old label:window sill, new label:file cabinet
# frame_006580,line_44, old label:window sill, new label:file cabinet
# frame_006580,line_45, old label:window sill, new label:window
# frame_006580,line_46, old label:window sill, new label:unlabeled
# processing frame_006660
# frame_006660,line_0, old label:window sill, new label:table
# frame_006660,line_1, old label:heater, new label:table
# frame_006660,line_2, old label:wall, new label:table
# frame_006660,line_3, old label:wall, new label:table
# frame_006660,line_4, old label:wall, new label:table
# frame_006660,line_8, old label:pipe, new label:table
# frame_006660,line_9, old label:window sill, new label:unlabeled
# frame_006660,line_12, old label:window, new label:unlabeled
# frame_006660,line_13, old label:window, new label:unlabeled
# frame_006660,line_15, old label:window sill, new label:table
# frame_006660,line_16, old label:window, new label:unlabeled
# frame_006660,line_18, old label:window sill, new label:table
# frame_006660,line_19, old label:pipe, new label:table
# frame_006660,line_20, old label:pipe, new label:table
# frame_006660,line_21, old label:window sill, new label:unlabeled
# frame_006660,line_22, old label:window sill, new label:unlabeled
# frame_006660,line_23, old label:window sill, new label:table
# frame_006660,line_25, old label:window, new label:unlabeled
# frame_006660,line_26, old label:heater, new label:table
# frame_006660,line_27, old label:window sill, new label:unlabeled
# frame_006660,line_28, old label:heater, new label:table
# frame_006660,line_29, old label:wall, new label:unlabeled
# frame_006660,line_30, old label:wall, new label:table
# frame_006660,line_31, old label:table, new label:office chair
# frame_006660,line_32, old label:table, new label:office chair
# frame_006660,line_33, old label:window sill, new label:unlabeled
# frame_006660,line_34, old label:window sill, new label:table
# frame_006660,line_35, old label:wall, new label:table
# processing frame_006740
# frame_006740,line_0, old label:wall, new label:file cabinet
# frame_006740,line_1, old label:office chair, new label:table
# frame_006740,line_3, old label:window sill, new label:unlabeled
# frame_006740,line_4, old label:heater, new label:file cabinet
# frame_006740,line_8, old label:window sill, new label:unlabeled
# frame_006740,line_9, old label:wall, new label:file cabinet
# frame_006740,line_10, old label:laptop stand, new label:laptop
# frame_006740,line_12, old label:window sill, new label:unlabeled
# frame_006740,line_16, old label:laptop stand, new label:table
# frame_006740,line_23, old label:wall, new label:file cabinet
# processing frame_006820
# frame_006820,line_16, old label:floor, new label:unlabeled
# frame_006820,line_23, old label:office chair, new label:table
# frame_006820,line_28, old label:table, new label:file cabinet
# frame_006820,line_31, old label:wall, new label:unlabeled
# processing frame_006900
# frame_006900,line_14, old label:table, new label:unlabeled
# frame_006900,line_17, old label:heater, new label:unlabeled
# frame_006900,line_29, old label:table, new label:unlabeled
# frame_006900,line_31, old label:laptop stand, new label:unlabeled
# processing frame_006980
# frame_006980,line_0, old label:storage cabinet, new label:unlabeled
# ...
# frame_008580,line_11, old label:monitor, new label:unlabeled
# frame_008580,line_12, old label:table, new label:unlabeled
# frame_008580,line_13, old label:window sill, new label:unlabeled
# frame_008580,line_15, old label:monitor, new label:unlabeled
# frame_008580,line_18, old label:monitor, new label:laptop stand
# frame_008580,line_19, old label:wall, new label:unlabeled
# frame_008580,line_20, old label:window sill, new label:unlabeled
# frame_008580,line_21, old label:monitor, new label:laptop stand
# frame_008580,line_22, old label:table, new label:unlabeled
# processing frame_008660
# frame_008660,line_4, old label:monitor, new label:unlabeled
# frame_008660,line_6, old label:monitor, new label:laptop stand
# frame_008660,line_8, old label:laptop stand, new label:box
# frame_008660,line_10, old label:monitor, new label:unlabeled
# frame_008660,line_11, old label:window sill, new label:file cabinet
# frame_008660,line_12, old label:wall, new label:file cabinet
# frame_008660,line_13, old label:monitor, new label:laptop stand
# frame_008660,line_17, old label:window sill, new label:file cabinet
# frame_008660,line_18, old label:wall, new label:file cabinet
# frame_008660,line_23, old label:table, new label:unlabeled
# frame_008660,line_25, old label:wall, new label:file cabinet
# frame_008660,line_27, old label:table, new label:unlabeled
# frame_008660,line_29, old label:laptop stand, new label:box
# frame_008660,line_30, old label:window sill, new label:file cabinet
# frame_008660,line_37, old label:table, new label:unlabeled
# frame_008660,line_38, old label:laptop stand, new label:box
# frame_008660,line_39, old label:wall, new label:file cabinet
# processing frame_008740
# frame_008740,line_2, old label:file cabinet, new label:table
# frame_008740,line_9, old label:file cabinet, new label:table
# frame_008740,line_10, old label:file cabinet, new label:unlabeled
# frame_008740,line_17, old label:trash bin, new label:unlabeled
# frame_008740,line_19, old label:table, new label:unlabeled
# frame_008740,line_20, old label:file cabinet, new label:unlabeled
# processing frame_008820
# frame_008820,line_0, old label:file cabinet, new label:table
# frame_008820,line_1, old label:file cabinet, new label:table
# frame_008820,line_2, old label:file cabinet, new label:unlabeled
# frame_008820,line_3, old label:storage cabinet, new label:floor
# frame_008820,line_4, old label:file cabinet, new label:table
# frame_008820,line_5, old label:file cabinet, new label:floor
# frame_008820,line_6, old label:file cabinet, new label:table
# frame_008820,line_7, old label:file cabinet, new label:unlabeled
# frame_008820,line_8, old label:file cabinet, new label:unlabeled
# frame_008820,line_9, old label:table, new label:unlabeled
# frame_008820,line_10, old label:file cabinet, new label:unlabeled
# frame_008820,line_11, old label:file cabinet, new label:unlabeled
# frame_008820,line_12, old label:file cabinet, new label:table
# frame_008820,line_13, old label:file cabinet, new label:table
# frame_008820,line_14, old label:file cabinet, new label:unlabeled
# frame_008820,line_16, old label:wall, new label:unlabeled
# frame_008820,line_17, old label:trash bin, new label:unlabeled
# frame_008820,line_18, old label:whiteboard, new label:unlabeled
# frame_008820,line_19, old label:whiteboard, new label:unlabeled
# frame_008820,line_20, old label:file cabinet, new label:unlabeled
# frame_008820,line_21, old label:storage cabinet, new label:unlabeled
# frame_008820,line_22, old label:file cabinet, new label:unlabeled
# frame_008820,line_23, old label:file cabinet, new label:table
# frame_008820,line_24, old label:file cabinet, new label:unlabeled
# frame_008820,line_25, old label:file cabinet, new label:unlabeled
# frame_008820,line_26, old label:file cabinet, new label:unlabeled
# processing frame_008900
# frame_008900,line_0, old label:storage cabinet, new label:door
# frame_008900,line_1, old label:storage cabinet, new label:wall
# frame_008900,line_2, old label:ceiling lamp, new label:unlabeled
# frame_008900,line_9, old label:wall, new label:unlabeled
# frame_008900,line_12, old label:wall, new label:unlabeled
# frame_008900,line_14, old label:storage cabinet, new label:door
# frame_008900,line_17, old label:wall, new label:unlabeled
# frame_008900,line_18, old label:wall, new label:unlabeled
# frame_008900,line_19, old label:wall, new label:unlabeled
# frame_008900,line_20, old label:wall, new label:unlabeled
# frame_008900,line_21, old label:wall, new label:unlabeled
# frame_008900,line_22, old label:wall, new label:unlabeled
# frame_008900,line_23, old label:wall, new label:unlabeled
# frame_008900,line_24, old label:pipe, new label:unlabeled
# processing frame_009020
# frame_009020,line_8, old label:wall, new label:unlabeled
# frame_009020,line_9, old label:wall, new label:unlabeled
# frame_009020,line_12, old label:floor, new label:sofa
# frame_009020,line_13, old label:monitor, new label:file cabinet
# frame_009020,line_14, old label:blinds, new label:unlabeled
# frame_009020,line_15, old label:door, new label:unlabeled
# frame_009020,line_16, old label:door, new label:unlabeled
# frame_009020,line_17, old label:window, new label:unlabeled
# frame_009020,line_19, old label:monitor, new label:unlabeled
# frame_009020,line_20, old label:monitor, new label:unlabeled
# frame_009020,line_21, old label:monitor, new label:laptop stand
# frame_009020,line_22, old label:blinds, new label:unlabeled
# frame_009020,line_23, old label:window sill, new label:unlabeled
# frame_009020,line_24, old label:door, new label:unlabeled
# frame_009020,line_25, old label:wall, new label:unlabeled
# frame_009020,line_27, old label:door, new label:unlabeled
# frame_009020,line_29, old label:wall, new label:unlabeled
# frame_009020,line_31, old label:wall, new label:unlabeled
# frame_009020,line_33, old label:monitor, new label:file cabinet
# frame_009020,line_35, old label:window sill, new label:unlabeled
# frame_009020,line_36, old label:window sill, new label:unlabeled
# processing frame_009220
# frame_009220,line_2, old label:monitor, new label:table
# frame_009220,line_3, old label:storage cabinet, new label:wall
# frame_009220,line_4, old label:file cabinet, new label:table
# frame_009220,line_5, old label:monitor, new label:unlabeled
# frame_009220,line_6, old label:storage cabinet, new label:wall
# frame_009220,line_8, old label:door, new label:wall
# frame_009220,line_9, old label:monitor, new label:office chair
# frame_009220,line_12, old label:floor, new label:sofa
# frame_009220,line_16, old label:monitor, new label:unlabeled
# frame_009220,line_17, old label:file cabinet, new label:table
# processing frame_009300
# frame_009300,line_0, old label:wall, new label:unlabeled
# frame_009300,line_1, old label:wall, new label:unlabeled
# frame_009300,line_2, old label:wall, new label:unlabeled
# frame_009300,line_3, old label:wall, new label:unlabeled
# frame_009300,line_4, old label:wall, new label:unlabeled
# frame_009300,line_5, old label:wall, new label:computer tower
# frame_009300,line_7, old label:wall, new label:unlabeled
# frame_009300,line_8, old label:wall, new label:unlabeled
# frame_009300,line_11, old label:storage cabinet, new label:door
# frame_009300,line_17, old label:storage cabinet, new label:door
# processing frame_009380
# frame_009380,line_0, old label:whiteboard, new label:wall
# frame_009380,line_12, old label:whiteboard, new label:wall
# processing frame_009460
# frame_009460,line_4, old label:blinds, new label:door
# frame_009460,line_5, old label:blinds, new label:door
# frame_009460,line_8, old label:ceiling, new label:unlabeled
# frame_009460,line_9, old label:wall, new label:unlabeled
# frame_009460,line_10, old label:blinds, new label:door
# frame_009460,line_13, old label:window sill, new label:unlabeled
# frame_009460,line_14, old label:blinds, new label:door
# frame_009460,line_15, old label:wall, new label:unlabeled
# frame_009460,line_16, old label:file cabinet, new label:table
# frame_009460,line_17, old label:wall, new label:unlabeled
# processing frame_009540
# frame_009540,line_1, old label:whiteboard, new label:wall
# frame_009540,line_2, old label:wall, new label:unlabeled
# frame_009540,line_3, old label:wall, new label:unlabeled
# frame_009540,line_12, old label:floor, new label:unlabeled
# frame_009540,line_14, old label:floor, new label:unlabeled
# processing frame_009620
# frame_009620,line_1, old label:file cabinet, new label:table
# frame_009620,line_2, old label:file cabinet, new label:table
# frame_009620,line_4, old label:whiteboard, new label:wall
# frame_009620,line_5, old label:file cabinet, new label:table
# processing frame_009700
# frame_009700,line_2, old label:blinds, new label:window
# frame_009700,line_3, old label:whiteboard, new label:wall
# frame_009700,line_4, old label:window sill, new label:unlabeled
# frame_009700,line_5, old label:blinds, new label:window
# frame_009700,line_6, old label:heater, new label:unlabeled
# frame_009700,line_7, old label:blinds, new label:window
# frame_009700,line_8, old label:wall, new label:unlabeled
# frame_009700,line_10, old label:blinds, new label:window
# frame_009700,line_14, old label:window, new label:unlabeled
# frame_009700,line_15, old label:heater, new label:unlabeled
# frame_009700,line_16, old label:wall, new label:unlabeled
# frame_009700,line_17, old label:wall, new label:unlabeled
# frame_009700,line_22, old label:file cabinet, new label:unlabeled
# frame_009700,line_25, old label:blinds, new label:window
# frame_009700,line_27, old label:file cabinet, new label:unlabeled
# processing frame_009780
# frame_009780,line_0, old label:wall, new label:unlabeled
# frame_009780,line_1, old label:window sill, new label:unlabeled
# frame_009780,line_2, old label:heater, new label:unlabeled
# frame_009780,line_4, old label:window sill, new label:unlabeled
# frame_009780,line_5, old label:heater, new label:unlabeled
# frame_009780,line_7, old label:window, new label:blinds
# frame_009780,line_14, old label:blinds, new label:unlabeled
# frame_009780,line_17, old label:heater, new label:unlabeled
# frame_009780,line_18, old label:wall, new label:unlabeled
# frame_009780,line_19, old label:wall, new label:floor
# frame_009780,line_21, old label:file cabinet, new label:unlabeled
# frame_009780,line_25, old label:file cabinet, new label:unlabeled
# frame_009780,line_27, old label:whiteboard, new label:unlabeled
# frame_009780,line_28, old label:whiteboard, new label:unlabeled
# frame_009780,line_30, old label:file cabinet, new label:unlabeled
# frame_009780,line_35, old label:file cabinet, new label:unlabeled
# frame_009780,line_36, old label:file cabinet, new label:unlabeled
# frame_009780,line_37, old label:file cabinet, new label:unlabeled
# processing frame_009860
# frame_009860,line_0, old label:file cabinet, new label:table
# frame_009860,line_1, old label:file cabinet, new label:table
# frame_009860,line_2, old label:file cabinet, new label:table
# frame_009860,line_3, old label:file cabinet, new label:table
# frame_009860,line_4, old label:file cabinet, new label:unlabeled
# frame_009860,line_5, old label:file cabinet, new label:unlabeled
# frame_009860,line_6, old label:file cabinet, new label:table
# frame_009860,line_7, old label:file cabinet, new label:unlabeled
# frame_009860,line_8, old label:file cabinet, new label:unlabeled
# frame_009860,line_9, old label:file cabinet, new label:unlabeled
# frame_009860,line_10, old label:file cabinet, new label:table
# frame_009860,line_11, old label:file cabinet, new label:unlabeled
# frame_009860,line_12, old label:file cabinet, new label:unlabeled
# frame_009860,line_13, old label:file cabinet, new label:unlabeled
# frame_009860,line_14, old label:file cabinet, new label:table
# frame_009860,line_15, old label:file cabinet, new label:unlabeled
# frame_009860,line_16, old label:file cabinet, new label:unlabeled
# frame_009860,line_17, old label:file cabinet, new label:unlabeled
# frame_009860,line_18, old label:file cabinet, new label:table
# frame_009860,line_19, old label:file cabinet, new label:unlabeled
# frame_009860,line_20, old label:file cabinet, new label:unlabeled
# frame_009860,line_21, old label:file cabinet, new label:unlabeled
# processing frame_010020
# frame_010020,line_1, old label:storage cabinet, new label:door
# frame_010020,line_2, old label:storage cabinet, new label:door
# frame_010020,line_3, old label:wall, new label:blinds
# frame_010020,line_5, old label:wall, new label:blinds
# frame_010020,line_6, old label:wall, new label:unlabeled
# frame_010020,line_7, old label:ceiling lamp, new label:unlabeled
# frame_010020,line_8, old label:wall, new label:blinds
# frame_010020,line_9, old label:wall, new label:blinds
# frame_010020,line_10, old label:wall, new label:blinds
# frame_010020,line_11, old label:wall, new label:blinds
# frame_010020,line_12, old label:ceiling lamp, new label:unlabeled
# frame_010020,line_13, old label:wall, new label:blinds
# frame_010020,line_17, old label:wall, new label:blinds
# processing frame_010340
# frame_010340,line_2, old label:pipe, new label:unlabeled
# frame_010340,line_3, old label:storage cabinet, new label:wall
# frame_010340,line_4, old label:storage cabinet, new label:unlabeled
# frame_010340,line_6, old label:ceiling lamp, new label:unlabeled
# frame_010340,line_7, old label:monitor, new label:file cabinet
# frame_010340,line_8, old label:door, new label:unlabeled
# frame_010340,line_9, old label:ceiling lamp, new label:unlabeled
# frame_010340,line_10, old label:monitor, new label:file cabinet
# frame_010340,line_11, old label:ceiling lamp, new label:unlabeled
# frame_010340,line_12, old label:pipe, new label:unlabeled
# frame_010340,line_13, old label:door, new label:unlabeled
# frame_010340,line_14, old label:monitor, new label:file cabinet
# frame_010340,line_15, old label:monitor, new label:unlabeled
# frame_010340,line_16, old label:monitor, new label:unlabeled
# frame_010340,line_17, old label:door, new label:wall
# frame_010340,line_20, old label:monitor, new label:unlabeled
# frame_010340,line_22, old label:monitor, new label:unlabeled
# frame_010340,line_23, old label:monitor, new label:file cabinet
# frame_010340,line_24, old label:monitor, new label:file cabinet
# frame_010340,line_25, old label:storage cabinet, new label:unlabeled
# frame_010340,line_26, old label:monitor, new label:unlabeled
# frame_010340,line_27, old label:monitor, new label:unlabeled
# frame_010340,line_29, old label:coat hanger, new label:unlabeled
# processing frame_010420
# frame_010420,line_1, old label:storage cabinet, new label:door
# frame_010420,line_2, old label:storage cabinet, new label:door
# frame_010420,line_3, old label:ceiling lamp, new label:unlabeled
# frame_010420,line_4, old label:storage cabinet, new label:door
# frame_010420,line_5, old label:storage cabinet, new label:door
# frame_010420,line_6, old label:ceiling lamp, new label:unlabeled
# frame_010420,line_7, old label:pipe, new label:unlabeled
# frame_010420,line_9, old label:wall, new label:unlabeled
# frame_010420,line_12, old label:storage cabinet, new label:door
# frame_010420,line_13, old label:ceiling lamp, new label:unlabeled
# frame_010420,line_14, old label:wall, new label:unlabeled
# frame_010420,line_17, old label:monitor, new label:unlabeled
# frame_010420,line_18, old label:monitor, new label:unlabeled
# frame_010420,line_19, old label:storage cabinet, new label:door
# frame_010420,line_20, old label:pipe, new label:unlabeled
# frame_010420,line_21, old label:wall, new label:unlabeled
# frame_010420,line_22, old label:wall, new label:unlabeled
# frame_010420,line_23, old label:wall, new label:unlabeled
# frame_010420,line_24, old label:pipe, new label:unlabeled
# frame_010420,line_25, old label:wall, new label:unlabeled
# frame_010420,line_26, old label:monitor, new label:door
# frame_010420,line_27, old label:wall, new label:unlabeled
# frame_010420,line_28, old label:wall, new label:unlabeled
# frame_010420,line_29, old label:monitor, new label:unlabeled
# frame_010420,line_31, old label:wall, new label:unlabeled
# frame_010420,line_32, old label:wall, new label:unlabeled
# frame_010420,line_33, old label:wall, new label:unlabeled
# frame_010420,line_34, old label:wall, new label:unlabeled
# scene a1d9da703c, average wrong prediction ratio: 0.17240143369175628, average missing prediction ratio: 0.2698924731182796

# %% [markdown]
# ### print wrong or missing prediction pairs
# - e.g. ('wall unlabeled', 146): there are 146 2D lines in query images which have semantics 'wall' but are not labeled.

# %%
sorted_wrong_labels = []
for key in wrong_labels:
    sorted_wrong_labels.append((key,wrong_labels[key]))
sorted_wrong_labels.sort(key=lambda x:x[1],reverse=True)
for wrong_label in sorted_wrong_labels:
    print(wrong_label)
# Out:
# ('wall unlabeled', 146)
# ('file cabinet table', 88)
# ('table unlabeled', 87)
# ('window unlabeled', 78)
# ('window sill unlabeled', 74)
# ('monitor unlabeled', 50)
# ('file cabinet unlabeled', 48)
# ('door unlabeled', 43)
# ('storage cabinet door', 35)
# ('laptop stand laptop', 30)
# ('storage cabinet unlabeled', 27)
# ('pipe unlabeled', 26)
# ('floor unlabeled', 24)
# ('office chair unlabeled', 22)
# ('heater unlabeled', 22)
# ('sofa sofa cushion', 21)
# ('table keyboard', 21)
# ('ceiling unlabeled', 20)
# ('ceiling lamp unlabeled', 19)
# ('monitor computer tower', 18)
# ('blinds unlabeled', 18)
# ('wall file cabinet', 16)
# ('door wall', 15)
# ('window sill file cabinet', 15)
# ('monitor file cabinet', 13)
# ('window sill table', 13)
# ('laptop stand unlabeled', 12)
# ('office chair table', 11)
# ('whiteboard unlabeled', 10)
# ('box file cabinet', 9)
# ('wall table', 9)
# ('whiteboard wall', 8)
# ('window sill window', 8)
# ('wall blinds', 8)
# ('coat hanger unlabeled', 7)
# ('monitor laptop stand', 7)
# ('blinds window', 6)
# ('floor table', 6)
# ('floor office chair', 6)
# ('file cabinet floor', 6)
# ('table monitor', 5)
# ('laptop unlabeled', 5)
# ('storage cabinet wall', 5)
# ('box unlabeled', 5)
# ('blinds door', 5)
# ('heater table', 5)
# ('pipe table', 5)
# ('storage cabinet file cabinet', 4)
# ('wall floor', 3)
# ('door window', 3)
# ('wall window', 3)
# ('keyboard unlabeled', 3)
# ('keyboard table', 3)
# ('ceiling lamp blinds', 3)
# ('floor box', 3)
# ('table laptop', 3)
# ('laptop stand table', 3)
# ('heater file cabinet', 3)
# ('laptop stand box', 3)
# ('floor door', 2)
# ('sofa cushion unlabeled', 2)
# ('coat hanger door', 2)
# ('ceiling lamp ceiling', 2)
# ('floor file cabinet', 2)
# ('computer tower unlabeled', 2)
# ('box table', 2)
# ('wall computer tower', 2)
# ('office chair floor', 2)
# ('pipe file cabinet', 2)
# ('table office chair', 2)
# ('trash bin unlabeled', 2)
# ('floor sofa', 2)
# ('wall sofa cushion', 1)
# ('floor sofa cushion', 1)
# ('keyboard monitor', 1)
# ('table floor', 1)
# ('monitor window', 1)
# ('wall door', 1)
# ('coat hanger file cabinet', 1)
# ('storage cabinet computer tower', 1)
# ('office chair file cabinet', 1)
# ('pipe ceiling', 1)
# ('storage cabinet office chair', 1)
# ('laptop stand computer tower', 1)
# ('table wall', 1)
# ('sofa wall', 1)
# ('ceiling lamp window', 1)
# ('sofa unlabeled', 1)
# ('window sill telephone', 1)
# ('file cabinet computer tower', 1)
# ('table laptop stand', 1)
# ('blinds wall', 1)
# ('file cabinet office chair', 1)
# ('computer tower floor', 1)
# ('office chair monitor', 1)
# ('laptop keyboard', 1)
# ('table file cabinet', 1)
# ('thermostat power socket', 1)
# ('window door', 1)
# ('window monitor', 1)
# ('laptop stand office chair', 1)
# ('storage cabinet floor', 1)
# ('monitor table', 1)
# ('monitor office chair', 1)
# ('window blinds', 1)
# ('monitor door', 1)

# %% [markdown]
# ### Output numpy files

# %%
data_query_pred = data_query
data_query_pred['scene_line_2D_semantic_ids'] = scene_line_2D_semantic_ids_new
data_query_pred['scene_label_missing_ratio'] = scene_missing_ratio
data_query_pred['scene_wrong_ratio'] = scene_wrong_ratio
np.save(project_root_dir+f'line_map_extractor/out/{scene_id}/query/{scene_id}_query_data_pred.npy',data_query_pred)
